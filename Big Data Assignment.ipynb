# %% [markdown]
# Part 1): Data preparation and preprocessing.
# - Perform data preparation and preprocessing for your analysis.
# - Submit your Jupyter notebook in your Github repository

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %%
# Loading the file

# df = pd.read_csv("data.csv", index_col=0) # The Id Col is now the index
df = pd.read_csv("data.csv", low_memory=False)
df['Date'] = pd.to_datetime(df['Date']) # The data is changed to datetime var type
print("Dataframe shape = ",df.shape) # print the shape of the data 
# df = df.dropna()
# The 
# df.head()
print(df['HighestSalary'])
# Out:
# Dataframe shape =  (318477, 13)
# 0          30
# 1          30
# 2          30
# 3          30
# 4          30
#          ...
# 318472    999
# 318473    999
# 318474    999
# 318475    999
# 318476    999
# Name: HighestSalary, Length: 318477, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318477 entries, 0 to 318476
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Id                 318477 non-null  object
#  1   Title              318477 non-null  object
#  2   Company            306473 non-null  object
#  3   Date               318477 non-null  datetime64[ns, UTC]
#  4   Location           197229 non-null  object
#  5   Area               122658 non-null  object
#  6   Classification     197229 non-null  object
#  7   SubClassification  197229 non-null  object
#  8   Requirement        318470 non-null  object
#  9   FullDescription    302302 non-null  object
#  10  LowestSalary       318477 non-null  int64
#  11  HighestSalary      318477 non-null  int64
#  12  JobType            302379 non-null  object
# dtypes: datetime64[ns, UTC](1), int64(2), object(10)
# memory usage: 31.6+ MB

# %% [markdown]
# ## Looking at the each job and the number of postings

# %%
by_class = df.groupby(['Classification'], as_index = False)['Id'].count().sort_values(by='Id', ascending=False)
fig = plt.figure(figsize=(10, 10))
sns.barplot(data=by_class, x=by_class.Id, y=by_class.Classification)
plt.title("Jobs and Number of Postings")
plt.xlabel("Number of Postings")
plt.ylabel("Classification")
# Out:
# Text(0, 0.5, 'Classification')

# %% [markdown]
# ## Looking at the job posts by salary range

# %%
by_lowSal = df.groupby(['LowestSalary'], as_index=False).count()
by_lowSal['labels'] = by_lowSal['LowestSalary']
by_lowSal.head()
# Out:
#    LowestSalary     Id  Title  Company   Date  Location   Area  \
# 0             0  62639  62639    59611  62639     38541  24399
# 1            30  23476  23476    22296  23476     16396   9811
# 2            40  34436  34436    32076  34436     21736  13264
# 3            50  27027  27027    25679  27027     16561  10755
# 4            60  28499  28499    27290  28499     18121  11393
# 5            70  28712  28712    27794  28712     17053  10456
# 6            80  24249  24249    23625  24249     12701   7562
# 7           100  27673  27673    27150  27673     17137  10575
# 8           120  24514  24514    24165  24514     14701   9481
# 9           150  25841  25841    25511  25841     15802   9916
#
#    Classification  SubClassification  Requirement  FullDescription  \
# 0           38541              38541        62637            56065
# 1           16396              16396        23476            22092
# 2           21736              21736        34435            33580
# 3           16561              16561        27026            26206
# 4           18121              18121        28499            27544
# 5           17053              17053        28712            27670
# 6           12701              12701        24248            23587
# 7           17137              17137        27671            26682
# 8           14701              14701        24514            23610
# 9           15802              15802        25841            24508
#
#    HighestSalary  JobType  labels
# 0          62639    56080       0
# 1          23476    22094      30
# 2          34436    33585      40
# 3          27027    26222      50
# 4          28499    27566      60
# 5          28712    27674      70
# 6          24249    23590      80
# 7          27673    26683     100
# 8          24514    23612     120
# 9          25841    24513     150

# %%
colors = sns.color_palette('pastel')[0:13]
fig = plt.figure(figsize=(10, 10))
plt.pie(data=by_lowSal, x=by_lowSal.Id, labels=by_lowSal.labels, colors=colors, autopct='%0.2f%%')
plt.title("Job Posts by Salary Range")
# Out:
# Text(0.5, 1.0, 'Job Posts by Salary Range')

# %%
# %matplotlib inline
matplotlib.patches.Circle(xy = (by_lowSal.Id, by_lowSal.labels))

# %% [markdown]
# ## Looking at the top locations for employment

# %%
# %matplotlib inline
locationDf = df[df['Location'].isna()==False]
locationDf = locationDf.groupby('Location').count()
locationDf['Location'] = locationDf.index
locationDf['Count'] = locationDf["Id"]
locationDf.head(10)
# Out:
#                                         Id  Title  Company  Date  Area  \
# Location
# ACT                                   6250   6250     6150  6250     0
# Adelaide                              6653   6653     6303  6653     0
# Adelaide Hills & Barossa               193    193      186   193     0
# Albany & Great Southern                150    150      149   150     0
# Albury Area                            416    416      404   416     0
# Alice Springs & Central Australia      301    301      287   301     0
# Bairnsdale & Gippsland                 378    378      371   378     0
# Ballarat & Central Highlands           603    603      580   603     0
# Bendigo, Goldfields & Macedon Ranges   808    808      788   808     0
# Blue Mountains & Central West          942    942      920   942     0
#
#                                       Classification  SubClassification  \
# Location
# ACT                                             6250               6250
# Adelaide                                        6653               6653
# Adelaide Hills & Barossa                         193                193
# Albany & Great Southern                          150                150
# Albury Area                                      416                416
# Alice Springs & Central Australia                301                301
# Bairnsdale & Gippsland                           378                378
# Ballarat & Central Highlands                     603                603
# Bendigo, Goldfields & Macedon Ranges             808                808
# Blue Mountains & Central West                    942                942
#
#                                       Requirement  FullDescription  \
# Location
# ACT                                          6250             5805
# Adelaide                                     6653             6312
# Adelaide Hills & Barossa                      193              182
# Albany & Great Southern                       150              134
# Albury Area                                   416              407
# Alice Springs & Central Australia             301              280
# Bairnsdale & Gippsland                        378              363
# Ballarat & Central Highlands                  603              566
# Bendigo, Goldfields & Macedon Ranges          808              760
# Blue Mountains & Central West                 942              886
#
#                                       LowestSalary  HighestSalary  JobType  \
# Location
# ACT                                           6250           6250     5807
# Adelaide                                      6653           6653     6313
# Adelaide Hills & Barossa                       193            193      182
# Albany & Great Southern                        150            150      134
# Albury Area                                    416            416      407
# Alice Springs & Central Australia              301            301      280
# Bairnsdale & Gippsland                         378            378      363
# Ballarat & Central Highlands                   603            603      566
# Bendigo, Goldfields & Macedon Ranges           808            808      760
# Blue Mountains & Central West                  942            942      886
#
#                                                                   Location  \
# Location
# ACT                                                                    ACT
# Adelaide                                                          Adelaide
# Adelaide Hills & Barossa                          Adelaide Hills & Barossa
# Albany & Great Southern                            Albany & Great Southern
# Albury Area                                                    Albury Area
# Alice Springs & Central Australia        Alice Springs & Central Australia
# Bairnsdale & Gippsland                              Bairnsdale & Gippsland
# Ballarat & Central Highlands                  Ballarat & Central Highlands
# Bendigo, Goldfields & Macedon Ranges  Bendigo, Goldfields & Macedon Ranges
# Blue Mountains & Central West                Blue Mountains & Central West
#
#                                       Count
# Location
# ACT                                    6250
# Adelaide                               6653
# Adelaide Hills & Barossa                193
# Albany & Great Southern                 150
# Albury Area                             416
# Alice Springs & Central Australia       301
# Bairnsdale & Gippsland                  378
# Ballarat & Central Highlands            603
# Bendigo, Goldfields & Macedon Ranges    808
# Blue Mountains & Central West           942

# %%
#Sort by descending to have the top 5 Cities at the top
locationDf = locationDf.sort_values(by="Count", ascending=False)
#Copy the top 5 countries
df2 = locationDf[:5].copy()
#Add a new row that will be all of the countries under the top 5, rename to
#others and set as the sum of all of their counts
new_row = pd.DataFrame(data = {'Location' : ['others'],
                              'Count' : [locationDf['Count'][5:].sum()]
                              })
#Overwrite the dataframe with the concatenation of these two
locationDf = pd.concat([df2, new_row])
locationDf.head(5)
# Out:
#                 Id    Title  Company     Date     Area  Classification  \
# Sydney     60765.0  60765.0  58919.0  60765.0  53778.0         60765.0
# Melbourne  46690.0  46690.0  44941.0  46690.0  41297.0         46690.0
# Brisbane   21466.0  21466.0  20612.0  21466.0  17412.0         21466.0
# Perth      13198.0  13198.0  12766.0  13198.0  10171.0         13198.0
# Adelaide    6653.0   6653.0   6303.0   6653.0      0.0          6653.0
#
#            SubClassification  Requirement  FullDescription  LowestSalary  \
# Sydney               60765.0      60765.0          57456.0       60765.0
# Melbourne            46690.0      46686.0          43821.0       46690.0
# Brisbane             21466.0      21466.0          20214.0       21466.0
# Perth                13198.0      13198.0          12287.0       13198.0
# Adelaide              6653.0       6653.0           6312.0        6653.0
#
#            HighestSalary  JobType   Location  Count
# Sydney           60765.0  57470.0     Sydney  60765
# Melbourne        46690.0  43827.0  Melbourne  46690
# Brisbane         21466.0  20221.0   Brisbane  21466
# Perth            13198.0  12298.0      Perth  13198
# Adelaide          6653.0   6313.0   Adelaide   6653

# %%
colors = sns.color_palette('pastel')[0:7]
fig = plt.figure(figsize=(10, 10))
plt.pie(data=locationDf, x=locationDf.Count, labels=locationDf.Location, colors=colors, autopct='%0.1f%%')
plt.title("Market share of locations")
# Out:
# Text(0.5, 1.0, 'Market share of locations')

# %% [markdown]
# ## Breaking down each location

# %% [markdown]
# ### Sydney:

# %%
Sydney_Df = df[df['Location'].isna()==False]
Sydney_Df = Sydney_Df[Sydney_Df['Location'] == "Sydney"]

Sydney_AreaDf = Sydney_Df.groupby('Area').count()
Sydney_AreaDf['Area'] = Sydney_AreaDf.index
Sydney_AreaDf['Count'] = Sydney_AreaDf['Id']

Sydney_ClassDf = Sydney_Df.groupby('Classification').count()
Sydney_ClassDf['Classification'] = Sydney_ClassDf.index
Sydney_ClassDf['Count'] = Sydney_ClassDf['Id']

Sydney_HighSalDf = Sydney_Df.groupby('HighestSalary').count()
Sydney_HighSalDf['HighSal'] = Sydney_HighSalDf.index
Sydney_HighSalDf['Count'] = Sydney_HighSalDf['Id']

print(Sydney_Df.shape)
Sydney_Df.head(20)
# print(Sydney_Df['HighestSalary'])
# Out:
# (60765, 13)
#           Id                                              Title  \
# 0   37404348                           Casual Stock Replenisher
# 4   37404308  Business Banking Contact Centre Specialist, Ni...
# 5   37404307  Business Banking Contact Centre Specialist, Ni...
# 19  37404247                                          Assembler
# 27  37404311        Investment Accountant - NAB Asset Servicing
# 5         Call Centre & Customer Service       Customer Service - Call Centre
# 19  Manufacturing, Transport & Logistics              Assembly & Process Work
# 27          Banking & Financial Services                 Analysis & Reporting
# 31  Manufacturing, Transport & Logistics  Warehousing, Storage & Distribution
# 34       Administration & Office Support            Administrative Assistants
# 36            Retail & Consumer Products                   Management - Store
# 41  Manufacturing, Transport & Logistics                       Road Transport
# 43            Retail & Consumer Products                    Retail Assistants
# 52                 Hospitality & Tourism                        Waiting Staff
# 58  Manufacturing, Transport & Logistics  Warehousing, Storage & Distribution
# 66  Manufacturing, Transport & Logistics              Assembly & Process Work
# 69                Real Estate & Property                       Administration
# 71  Manufacturing, Transport & Logistics                       Road Transport
# 72  Manufacturing, Transport & Logistics                       Road Transport
# 73  Manufacturing, Transport & Logistics                       Road Transport
# 83                Real Estate & Property                    Residential Sales
# 84                 Hospitality & Tourism        Front Office & Guest Services
# 86                 Hospitality & Tourism        Front Office & Guest Services
#
#                                           Requirement FullDescription  \
# 0   Our Casual Stock Replenishers pride themselves...             NaN
# 4   We are seeking highly articulate, enthusiastic...             NaN
# 5   We are seeking highly articulate, enthusiastic...             NaN
# 19  Our Client, located in Sydney West, has roles ...             NaN
# 27  Entry level opportunity in Investment Accounti...             NaN
# 31  We are currently seeking a General Hand to joi...             NaN
# 34  Our Client, is a icon in the transport busines...             NaN
# 36  Seeking an experienced Store Manager who has a...             NaN
# 41  We have a variety of industries to work in, gi...             NaN
# 43  Our client is a giant in luxury furniture!  Jo...             NaN
# 52  Hamilton Island's flagship venue is seeking a ...             NaN
# 58  We are currently seeking Day Shift Warehouse w...             NaN
# 66  Wanted a General Hand who is willing to get th...             NaN
# 69  We are looking for an EXPERIENCED receptionist...             NaN
# 71                                         MC driver              NaN
# 72                                         MC driver              NaN
# 73                                         MC driver              NaN
# 83  Our newest office, opening in St George are lo...             NaN
# 84  In your role as Front Office Manager you will ...             NaN
# 86  In your role as Front Office Manager you will ...             NaN
#
#     LowestSalary  HighestSalary JobType
# 0              0             30     NaN
# 4              0             30     NaN
# 5              0             30     NaN
# 19             0             30     NaN
# 27             0             30     NaN
# 31             0             30     NaN
# 34             0             30     NaN
# 36             0             30     NaN
# 41             0             30     NaN
# 43             0             30     NaN
# 52             0             30     NaN
# 58             0             30     NaN
# 66             0             30     NaN
# 69             0             30     NaN
# 71             0             30     NaN
# 72             0             30     NaN
# 73             0             30     NaN
# 83             0             30     NaN
# 84             0             30     NaN
# 86             0             30     NaN

# %%
print("Sydney Areas")
Sydney_AreaDf.head(10)
# Out:
# Sydney Areas
#                                           Id    Title  Company     Date  \
# CBD, Inner West & Eastern Suburbs    29059.0  29059.0  28356.0  29059.0
# Parramatta & Western Suburbs          8769.0   8769.0   8399.0   8769.0
# North Shore & Northern Beaches        6656.0   6656.0   6417.0   6656.0
# South West & M5 Corridor              3190.0   3190.0   2998.0   3190.0
# Southern Suburbs & Sutherland Shire   2239.0   2239.0   2164.0   2239.0
# 0                                        NaN      NaN      NaN      NaN
#
#                                      Location  Classification  \
# CBD, Inner West & Eastern Suburbs     29059.0         29059.0
#
#                                         Requirement  FullDescription  \
# Information & Communication Technology       9548.0           8946.0
# Hospitality & Tourism                        4074.0           3741.0
# Trades & Services                            4026.0           3866.0
# Accounting                                   4010.0           3778.0
# Healthcare & Medical                         3339.0           3225.0
# Manufacturing, Transport & Logistics         3308.0           3170.0
# Administration & Office Support              3178.0           2954.0
# Sales                                        3139.0           3018.0
# Construction                                 2920.0           2803.0
# Banking & Financial Services                 2571.0           2424.0
#
#                                         LowestSalary  HighestSalary  JobType  \
# Information & Communication Technology        9548.0         9548.0   8946.0
# Hospitality & Tourism                         4074.0         4074.0   3745.0
# Trades & Services                             4026.0         4026.0   3866.0
# Accounting                                    4010.0         4010.0   3778.0
# Healthcare & Medical                          3339.0         3339.0   3225.0
# Manufacturing, Transport & Logistics          3308.0         3308.0   3171.0
# Administration & Office Support               3178.0         3178.0   2954.0
# Sales                                         3139.0         3139.0   3018.0
# Construction                                  2920.0         2920.0   2803.0
# Banking & Financial Services                  2571.0         2571.0   2424.0
#
#                                                                 Classification  \
# Information & Communication Technology  Information & Communication Technology
# Hospitality & Tourism                                    Hospitality & Tourism
# Trades & Services                                            Trades & Services
# Accounting                                                          Accounting
# Healthcare & Medical                                      Healthcare & Medical
# Manufacturing, Transport & Logistics      Manufacturing, Transport & Logistics
# Administration & Office Support                Administration & Office Support
# Sales                                                                    Sales
# Construction                                                      Construction
# Banking & Financial Services                      Banking & Financial Services
#
#                                         Count
# Information & Communication Technology   9548
# Hospitality & Tourism                    4074
# Trades & Services                        4026
# Accounting                               4010
# Healthcare & Medical                     3339
# Manufacturing, Transport & Logistics     3308
# Administration & Office Support          3178
# Sales                                    3139
# Construction                             2920
# Banking & Financial Services             2571

# %%
print("1st Date:")
print(Sydney_Df['Date'].iloc[0].day)
print(Sydney_Df['Date'].iloc[0].month)
print(Sydney_Df['Date'].iloc[0].year)
print("Last Date:")
print(Sydney_Df['Date'].iloc[-1].day)
print(Sydney_Df['Date'].iloc[-1].month)
print(Sydney_Df['Date'].iloc[-1].year)

for i in Sydney_Df['Date']:
    if Sydney_Df['Date'].iloc[i].month == 10 and Sydney_Df['Date'].iloc[i].day <= 15:
        ..............
    elif Sydney_Df['Date'].iloc[i].month == 10 and Sydney_Df['Date'].iloc[i].day > 15 and Sydney_Df['Date'].iloc[i].day <= 31:
        ...............
    elif Sydney_Df['Date'].iloc[i].month == 11 and .....
    
    .....
# Out:
# 1st Date:
# 7
# 10
# 2018
# Last Date:
# 29
# 11
# 2018

# %%
(H, edges) = np.histogram(Sydney_Df['Date'], 10)
print(edges)

# %%
print("Sydney Most Common Highest Salaries")
Sydney_HighSalDf
# Out:
# Sydney Most Common Highest Salaries
#                   Id  Title  Company   Date  Location   Area  Classification  \
# HighestSalary
# 30             11753  11753    11364  11753     11753  10488           11753
# 40              3969   3969     3791   3969      3969   3791            3969
# 50              5371   5371     5029   5371      5371   5005            5371
# 60              4861   4861     4655   4861      4861   4522            4861
# 70              5288   5288     5067   5288      5288   4784            5288
# 80              5033   5033     4899   5033      5033   4396            5033
# 100             3738   3738     3646   3738      3738   3218            3738
# 120             5579   5579     5488   5579      5579   4839            5579
# 150             5706   5706     5639   5706      5706   4869            5706
# 200             6274   6274     6197   6274      6274   5251            6274
# 999             3193   3193     3144   3193      3193   2615            3193
#
#                SubClassification  Requirement  FullDescription  LowestSalary  \
# HighestSalary
# 30                         11753        11753            10090         11753
# 40                          3969         3969             3727          3969
# 50                          5371         5371             5257          5371
# 60                          4861         4861             4718          4861
# 70                          5288         5288             5143          5288
# 80                          5033         5033             4867          5033
# 100                         3738         3738             3678          3738
# 120                         5579         5579             5410          5579
# 150                         5706         5706             5508          5706
# 200                         6274         6274             6038          6274
# 999                         3193         3193             3020          3193
#
#                JobType  HighSal  Count
# HighestSalary
# 30               10092       30  11753
# 40                3728       40   3969
# 50                5259       50   5371
# 60                4721       60   4861
# 70                5145       70   5288
# 80                4868       80   5033
# 100               3678      100   3738
# 120               5411      120   5579
# 150               5508      150   5706
# 200               6040      200   6274
# 999               3020      999   3193

# %%
#Sort by descending to have the top 5 AREAS at the top
Sydney_AreaDf = Sydney_AreaDf.sort_values(by="Count", ascending=False)
#Copy the top 5 countries
df2 = Sydney_AreaDf[:5].copy()
#Add a new row that will be all of the AREAS under the top 5, rename to
#others and set as the sum of all of their counts
new_row = pd.DataFrame(data = {'Area' : ['others'],
                              'Count' : [Sydney_AreaDf['Count'][5:].sum()]
                              })
#Overwrite the dataframe with the concatenation of these two
Sydney_AreaDf = pd.concat([df2, new_row])

#Sort by descending to have the top 5 CLASSIFICATIONS at the top
Sydney_ClassDf = Sydney_ClassDf.sort_values(by="Count", ascending=False)
#Copy the top 5 countries
df2 = Sydney_ClassDf[:15].copy()
#Add a new row that will be all of the CLASSIFICATIONS under the top 5, rename to
#others and set as the sum of all of their counts
new_row = pd.DataFrame(data = {'Classification' : ['others'],
                              'Count' : [Sydney_ClassDf['Count'][15:].sum()]
                              })
#Overwrite the dataframe with the concatenation of these two
Sydney_ClassDf = pd.concat([df2, new_row])
Sydney_AreaDf.head(5)
# Out:
#                                           Id    Title  Company     Date  \
# CBD, Inner West & Eastern Suburbs    29059.0  29059.0  28356.0  29059.0
# Parramatta & Western Suburbs          8769.0   8769.0   8399.0   8769.0
# North Shore & Northern Beaches        6656.0   6656.0   6417.0   6656.0
# South West & M5 Corridor              3190.0   3190.0   2998.0   3190.0
# Southern Suburbs & Sutherland Shire   2239.0   2239.0   2164.0   2239.0
#
#                                      Location  Classification  \
# CBD, Inner West & Eastern Suburbs     29059.0         29059.0
# Parramatta & Western Suburbs           8769.0          8769.0
# North Shore & Northern Beaches         6656.0          6656.0
# South West & M5 Corridor               3190.0          3190.0
# Southern Suburbs & Sutherland Shire    2239.0          2239.0
#
#                                      SubClassification  Requirement  \
# CBD, Inner West & Eastern Suburbs              29059.0      29059.0
# Parramatta & Western Suburbs                    8769.0       8769.0
# North Shore & Northern Beaches                  6656.0       6656.0
# South West & M5 Corridor                        3190.0       3190.0
# Southern Suburbs & Sutherland Shire             2239.0       2239.0
#
#                                      FullDescription  LowestSalary  \
# Manufacturing, Transport & Logistics          3308.0         3308.0   3171.0
# Administration & Office Support               3178.0         3178.0   2954.0
# Sales                                         3139.0         3139.0   3018.0
# Construction                                  2920.0         2920.0   2803.0
# Banking & Financial Services                  2571.0         2571.0   2424.0
#
#                                                                 Classification  \
# Information & Communication Technology  Information & Communication Technology
# Hospitality & Tourism                                    Hospitality & Tourism
# Trades & Services                                            Trades & Services
# Accounting                                                          Accounting
# Healthcare & Medical                                      Healthcare & Medical
# Manufacturing, Transport & Logistics      Manufacturing, Transport & Logistics
# Administration & Office Support                Administration & Office Support
# Sales                                                                    Sales
# Construction                                                      Construction
# Banking & Financial Services                      Banking & Financial Services
#
#                                         Count
# Information & Communication Technology   9548
# Hospitality & Tourism                    4074
# Trades & Services                        4026
# Accounting                               4010
# Healthcare & Medical                     3339
# Manufacturing, Transport & Logistics     3308
# Administration & Office Support          3178
# Sales                                    3139
# Construction                             2920
# Banking & Financial Services             2571

# %%
(H, edges) = np.histogram(Sydney_Df['HighestSalary'], 10)
print(edges)

range1_Count = 0
range2_Count = 0
range3_Count = 0
range4_Count = 0
range5_Count = 0
range6_Count = 0
range7_Count = 0
range8_Count = 0
range9_Count = 0
range10_Count = 0
for i in Sydney_Df['HighestSalary']:
    if i >= edges[0] and i <= edges[1]:
        range1_Count += 1
    elif i > edges[1] and i <= edges[2]:
        range2_Count += 1
    elif i > edges[2] and i <= edges[3]:
        range3_Count += 1
    elif i > edges[3] and i <= edges[4]:
        range4_Count += 1
    elif i > edges[4] and i <= edges[5]:
        range5_Count += 1
    elif i > edges[5] and i <= edges[6]:
        range6_Count += 1
    elif i > edges[6] and i <= edges[7]:
        range7_Count += 1 
    elif i > edges[7] and i <= edges[8]:
        range8_Count += 1 
    elif i > edges[8] and i <= edges[9]:
        range9_Count += 1 
    elif i > edges[9] and i <= edges[10]:
        range10_Count += 1 
print("Range 1:",range1_Count)
print("Range 2:",range2_Count)
print("Range 3:",range3_Count)
print("Range 4:",range4_Count)
print("Range 5:",range5_Count)
print("Range 6:",range6_Count)
print("Range 7:",range7_Count)
print("Range 8:",range8_Count)
print("Range 9:",range9_Count)
print("Range 10:",range10_Count)

print("Sum of range frequency:",range1_Count+range2_Count+range3_Count+range4_Count+range5_Count+range6_Count+range7_Count+range8_Count+range9_Count+range10_Count)
print("Total number of values from Sydney data:",Sydney_Df.shape[0])

HighestSalary_Data = {'HighestSalaryRange':['{:f}-{:f}'.format(edges[0], edges[1]),
                                             '{:f}-{:f}'.format(edges[1], edges[2]),
                                             '{:f}-{:f}'.format(edges[2], edges[3]),
                                             '{:f}-{:f}'.format(edges[3], edges[4]),
                                             '{:f}-{:f}'.format(edges[4], edges[5]),
                                             '{:f}-{:f}'.format(edges[5], edges[6]),
                                             '{:f}-{:f}'.format(edges[6], edges[7]),
                                             '{:f}-{:f}'.format(edges[7], edges[8]),
                                             '{:f}-{:f}'.format(edges[8], edges[9]),
                                             '{:f}-{:f}'.format(edges[9], edges[10])],
                     'RangeFrequency':[range1_Count, range2_Count, range3_Count,
                                        range4_Count, range5_Count, range6_Count,
                                        range7_Count, range8_Count, range9_Count,
                                        range10_Count]}


# Sydney_HighestSalary_Df = pd.DataFrame(columns = ['Area', 'Classification','Highest Salary Range','Range Count'])
Sydney_HighestSalary_Df = pd.DataFrame(HighestSalary_Data)
Sydney_HighestSalary_Df.head(10)
# Out:
# [ 30.  126.9 223.8 320.7 417.6 514.5 611.4 708.3 805.2 902.1 999. ]
# Range 1: 45592
# Range 2: 11980
# Range 3: 0
# Range 4: 0
# Range 5: 0
# Range 6: 0
# Range 7: 0
# Range 8: 0
# Range 9: 0
# Range 10: 3193
# Sum of range frequency: 60765
# Total number of values from Sydney data: 60765
#       HighestSalaryRange  RangeFrequency
# 0   30.000000-126.900000           45592
# 1  126.900000-223.800000           11980
# 2  223.800000-320.700000               0
# 3  320.700000-417.600000               0
# 4  417.600000-514.500000               0
# 5  514.500000-611.400000               0
# 6  611.400000-708.300000               0
# 7  708.300000-805.200000               0
# 8  805.200000-902.100000               0
# 9  902.100000-999.000000            3193

# %% [markdown]
# USE HISTOGRAM BINS TO DETERMINE RANGES

# %%
print(HighestSalary_Data['RangeFrequency'])
# Out:
# [45592, 11980, 0, 0, 0, 0, 0, 0, 0, 3193]

# %%
colors = sns.color_palette('pastel')[0:7]
# %matplotlib qt
# %matplotlib inline
fig = plt.figure(figsize=(20, 20))
plt.subplot(221)
plt.pie(data=Sydney_AreaDf, x=Sydney_AreaDf.Count, labels=Sydney_AreaDf.Area, colors=colors, autopct='%0.1f%%')
plt.title("Market share of Areas in Sydney")

plt.subplot(222)
plt.pie(data=Sydney_ClassDf, x=Sydney_ClassDf.Count, labels=Sydney_ClassDf.Classification, colors=colors, autopct='%0.1f%%')
plt.title("Market share of Job Classifications in Sydney")

plt.subplot(223)
plt.pie(data=HighestSalary_Data, x=HighestSalary_Data['RangeFrequency'], labels=HighestSalary_Data['HighestSalaryRange'], colors=colors, autopct='%0.1f%%')
plt.title("Highest Salary Ranges")

plt.subplots_adjust(wspace = 0.315)

# %% [markdown]
# NEED TO DO TWO VARIABLE ANALYSIS. E.G. WHERE ARE THE HIGHEST PAID SALARIES IN EACH AREA?

# %% [markdown]
# Need to prime the data for analysis section so need:

# %% [markdown]
# 1. What is the sector, sub-sector of each job?
# 2. Where is the location of each job?
# 3. What is the range of salaries for each job?

# %% [markdown]
# Now, study the market by locations:
# 1. What is the market size in each city? What are the hottest job sectors in each city?
# 2. Which range of salary is common in each city? Where are the employees more well-paid?
# 3. Can you detect the pattern of posting: e.g. Are more jobs posted at the beginning of the month?

# %% [markdown]
# Now, study the market by sectors:
# 1. Which sectors keep the highest market share?
# 2. In each sector, which sub-sectors are the main spotlights?
# 3. What is the salary range for each sector/sub-sector? Can you compare the salary range between sectors/subsectors?
# 4. What is the trending of the market, i.e., if a high school student asks you which subject should he/she learn in the university (to guarantee a job in the future), what is your advice?
# 5. Can you detect which skills are required in each sector?

# %% [markdown]
# Keep in mind these sectors / locations that need to be considered when cleaning the data. Think about sub data frames that need to be made and think of the correlations that need to be found.
